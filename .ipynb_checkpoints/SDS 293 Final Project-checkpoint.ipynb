# %%
library(tree)
library(randomForest)
Starbucks = read.csv("starbucks.csv", header=TRUE)

set.seed(1)
train = sample(1:nrow(Starbucks), nrow(Starbucks)/2)
starbucks.test = Starbucks[-train, "avg_stars"]

tree.starbucks = tree(avg_stars~., Starbucks, subset=train)

bag.starbucks = randomForest(avg_stars~., data=Starbucks, subset=train, importance=TRUE, ntree=25)


dim(Starbucks)
# Out:
# Warning message:
# : package 'tree' was built under R version 3.2.5Warning message:
# : package 'randomForest' was built under R version 3.2.5randomForest 4.6-12
# Type rfNews() to see new features/changes/bug fixes.
# [1] 410   8

# %%
yhat.bag = predict(bag.starbucks,newdata=Starbucks[-train,])
mean((yhat.bag-starbucks.test)^2)
# Out:
# [1] 0.3538793

# %%
library(gbm)
set.seed(1)

boost.starbucks = gbm(avg_stars~., data=Starbucks[train,], distribution="gaussian", n.trees = 5000, interaction.depth=4)
summary(boost.starbucks)
# Out:
#                                               var   rel.inf
# percent_white_people         percent_white_people 26.346505
# total_population                 total_population 23.582815
# yearly_household_income   yearly_household_income 21.646368
# people_per_household         people_per_household 19.491116
# price_range                           price_range  4.513490
# is_wheelchair_accessible is_wheelchair_accessible  4.419707
# has_wifi                                 has_wifi  0.000000
# plot without title

# %%
tree.starbucks = tree(avg_stars~.-avg_stars, Starbucks, subset=train)
summary(tree.starbucks)
# Out:
# Regression tree:
# tree(formula = avg_stars ~ . - avg_stars, data = Starbucks, subset = train)
# Variables actually used in tree construction:
# [1] "percent_white_people"     "price_range"
# [3] "total_population"         "yearly_household_income"
# [5] "is_wheelchair_accessible" "people_per_household"
# Number of terminal nodes:  20
# Residual mean deviance:  0.2823 = 52.22 / 185
# Distribution of residuals:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -1.38900 -0.36360  0.03846  0.00000  0.30770  1.53800

# %%
plot(tree.starbucks)
text(tree.starbucks, pretty = 0)
# Out:
# plot without title

# %%
cv.starbucks = cv.tree(tree.starbucks)
plot(cv.starbucks$size, cv.starbucks$dev, type="b")
which.min(cv.starbucks$dev)
# Out:
# [1] 13
# plot without title

# %%
prune.starbucks2 = prune.tree(tree.starbucks, best = 2)
plot(prune.starbucks2)
text(prune.starbucks2, pretty = 0)
# Out:
# plot without title

# %%
prune.starbucks4 = prune.tree(tree.starbucks, best = 4)
plot(prune.starbucks4)
text(prune.starbucks4, pretty = 0)
# Out:
# plot without title

# %%
yhat = predict(prune.starbucks4, newdata = Starbucks[-train,])
mean((yhat-Starbucks[-train, "avg_stars"])^2)

plot(yhat,Starbucks[-train, "avg_stars"])
abline(0,1)
# Out:
# [1] 0.3610376
# plot without title

# %%
set.seed(1)
bag.starbucks = randomForest(avg_stars~., data = Starbucks, subset = train, mtry = 7, importance = TRUE)
bag.starbucks
# Out:
# Call:
#  randomForest(formula = avg_stars ~ ., data = Starbucks, mtry = 7,      importance = TRUE, subset = train)
#                Type of random forest: regression
#                      Number of trees: 500
# No. of variables tried at each split: 7
#
#           Mean of squared residuals: 0.4882735
#                     % Var explained: -21.89

# %%
yhat.bag = predict(bag.starbucks,newdata=Starbucks[-train,])
plot(yhat.bag, Starbucks[-train, "avg_stars"])
abline(0,1)
mean((yhat.bag-Starbucks[-train, "avg_stars"])^2)
# Out:
# [1] 0.3675866
# plot without title

# %%
yhat.boost = predict(boost.starbucks,newdata=Starbucks[-train,], n.trees=5000)
mean((yhat.boost-starbucks.test)^2)
# Out:
# [1] 0.3614004

# %%
# Then need to do best-subset selection

library(leaps)
regfit.full = regsubsets(avg_stars~., data=Starbucks)
reg.summary = summary(regfit.full)

# %%
par(mfrow=c(2,2))
plot(reg.summary$rss, xlab = "Number of variables", ylab = "RSS", type = "l")
plot(reg.summary$adjr2, xlab = "Number of variables", ylab = "Adjusted RSq", type="l")

which.max(reg.summary$adjr2) #2
points(11,reg.summary$adjr2[3], col ="red", cex = 2, pch = 20)

plot(reg.summary$cp, xlab = "Number of Variables", ylab = "Cp", type = "l")
which.min(reg.summary$cp) # 2
points(10, reg.summary$cp[2], col = "red", cex = 2, pch = 20)

plot(reg.summary$bic, xlab = "Number of Variables", ylab = "BIC", type = "l")
which.min(reg.summary$bic) # 1
points(6, reg.summary$bic[1], col = "red", cex = 2, pch = 20)
# Out:
# [1] 3
# [1] 2
# [1] 1
# plot without title

# %%
summary(regfit.full)
coef(regfit.full, 3)
# Out:
# Subset selection object
# Call: regsubsets.formula(avg_stars ~ ., data = Starbucks)
# 7 Variables  (and intercept)
#                          Forced in Forced out
# total_population             FALSE      FALSE
# percent_white_people         FALSE      FALSE
# has_wifi                     FALSE      FALSE
# yearly_household_income      FALSE      FALSE
# price_range                  FALSE      FALSE
# people_per_household         FALSE      FALSE
# is_wheelchair_accessible     FALSE      FALSE
# 1 subsets of each size up to 7
# Selection Algorithm: exhaustive
#          total_population percent_white_people has_wifi yearly_household_income
# 1  ( 1 ) " "              "*"                  " "      " "
# 2  ( 1 ) " "              "*"                  " "      " "
# 3  ( 1 ) " "              "*"                  "*"      " "
# 4  ( 1 ) " "              "*"                  "*"      " "
# 5  ( 1 ) "*"              "*"                  "*"      " "
# ...

# %%
#keeps = c("total_population", "avg_stars", "percent_white_people", "has_wifi", "yearly_household_income", "price_range", "people_per_household", "is_wheelchair_accessible")
#head(Starbucks[keeps])
pr.out=prcomp(Starbucks, scale=TRUE)

# %%
biplot(pr.out, scale = 0)
# Out:
# plot without title
